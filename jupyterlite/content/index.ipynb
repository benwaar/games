# %% [markdown]
# # 🚀 Utala: KAOS 9
#
# ## A Competitive 2-Player Tactical Duel
#
# Welcome to **Utala: KAOS 9** — a strategic card game playable with any standard 52-card deck!
#
# This is an interactive research project exploring game AI through multiple agent types:
# - **Random** baseline
# - **Heuristic** strategic agents
# - **Monte Carlo** search-based agents
#
# Everything is **text-based, inspectable, and hackable**.
#
# ---
#
# ## 🎮 Game Modes
#
# Choose your experience:
#
# ### [▶️ Play vs AI](play-vs-ai.ipynb)
# **Interactive gameplay** — test your skills against AI opponents
# - Select difficulty level (Random, Heuristic, Monte Carlo)
# - Make strategic placement and dogfight decisions
# - Full game with real-time input
#
# ### [👀 Watch Tournament](watch-tournament.ipynb)
# **AI vs AI battles** — observe different strategies compete
# - See how agents think and play
# - Compare win rates
# - Understand strategic patterns
#
# ### [🔬 Explore Agents](explore-agents.ipynb)
# **Educational deep dive** — learn how agents work
# - View agent source code
# - Compare strategies
# - Experiment with parameters
#
# ---
#
# ## 📖 Game Rules
#
# **Utala: KAOS 9** is a tactical 3×3 grid combat game:
#
# 1. **Placement Phase**: Take turns placing your 9 rocketmen (cards 2-10) on the board
#    - Cards 2, 3, 9, 10 are placed face-down for deception
#    - Contest opponent squares for tactical advantage
#
# 2. **Dogfight Phase**: Resolve contested squares through turn-based combat
#    - Use your 4 weapons (Ace, King, Queen, Jack) strategically
#    - Underdog acts first
#    - Draw Kaos cards (1-13) for resolution
#
# 3. **Win Condition**: Get 3 in a row, or control the most squares
#
# **[Download Full Rules PDF](../files/utala-kaos-9-rules.pdf)**
#
# ---
#
# ## 🎯 Quick Start
#
# **To play right now:**
# 1. Click **[▶️ Play vs AI](play-vs-ai.ipynb)** above
# 2. Run the first cell to install the game
# 3. Follow the prompts to select your opponent
# 4. Enjoy!
#
# **No installation required** — everything runs in your browser!
#
# ---
#
# ## 🧠 About This Project
#
# This is **Phase 1** of a game AI research project:
# - Pure Python implementation (no ML frameworks)
# - Deterministic game engine with explicit RNG
# - Baseline agents to establish skill ceiling
# - Full test coverage (79 tests, 94% coverage)
#
# **Project ethos:** Understanding algorithms by building them, seeing how different approaches *think*, learning by stripping problems down to their **nuts and bolts**.
#
# ---
#
# ## 🔗 Links
#
# - **[GitHub Repository](https://github.com/benwaar/games)** — View source code
# - **[Game Rules PDF](../files/utala-kaos-9-rules.pdf)** — Full rulebook
# - **[Screenshot](../files/screenshot.png)** — Terminal gameplay example
#
# ---
#
# **Ready to play?** Choose a game mode above and start!
#
# Good luck and have fun! 🚀
